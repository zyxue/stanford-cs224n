# %% [markdown]
# http://web.stanford.edu/class/cs224n/assignment2/assignment2-soln.pdf

# %% [markdown]
# Recorded computation graphs from tensorboard

# %%
from IPython.display import Image

# %% [markdown]
# # Softmax

# %%
Image('./softmax-graph.png', width=700)

# %% [markdown]
# # Cross-entropy

# %%
Image('./cross-entropy-graph.png', width=400)
