# %% [markdown]
# http://web.stanford.edu/class/cs224n/assignment1/assignment1_soln.pdf

# %% [markdown]
# # (b)

# %% [markdown]
# Regularization is used to reduce overfitting.

# %% [markdown]
# # (d)

# %% [markdown]
# `python q4_sentiment.py --pretrained`
#
# ```
# Best regularization value: 1.15E+01
# Test accuracy (%): 37.466063
# ```

# %% [markdown]
# `python q4_sentiment.py --yourvectors`
#
# ```
# Best regularization value: 2.33E-02
# Test accuracy (%): 30.180995
# ```

# %% [markdown]
# Reasons why GloVe vectors perform better:
#
# 1. They take co-ocurrence into account
# 1. Their hyperparameters may be better tuned
# 1. They may be trained on more data

# %% [markdown]
# # (e)

# %%
import pandas as pd

from IPython.display import display, Image, HTML

# %%
Image('./q4_reg_v_acc.png')

# %% [markdown]
# This is result based on pretrained vectors.
#
# When regularization is small, it tends to overfit, to underfit otherwise. The best regularization is around 10e1.7.

# %% [markdown]
# # (f)

# %%
Image('./q4_dev_conf.png')

# %% [markdown]
# The models seem to have quite some difficulty in distinguishing - examples with neutral and + examples.

# %% [markdown]
# # (g)

# %%
df = pd.read_csv('./q4_dev_pred.txt', sep='\t')

# %%
df.head()
# Out:
#    True  Predicted                                               Text
# 0     3          4  it 's a lovely film with lovely performances b...
# 1     2          1  no one goes unindicted here , which is probabl...
# 2     3          1  and if you 're not nearly moved to tears by a ...
# 3     4          4                   a warm , funny , engaging film .
# 4     4          3  uses sharp humor and insight into human nature...

# %%
df['diff'] = (df.True - df.Predicted).abs()

# %%
df.sort_values('diff', ascending=False).head()
# Out:
#      True  Predicted                                               Text  diff
# 970     0          4  a lackluster , unessential sequel to the class...     4
# 686     0          3  whaley 's determination to immerse you in shee...     3
# 971     0          3  samira makhmalbaf 's new film blackboards is m...     3
# 972     3          0  ... routine , harmless diversion and little el...     3
# 754     0          3  a very long movie , dull in stretches , with e...     3

# %%
df.loc[970].Text
# Out:
# "a lackluster , unessential sequel to the classic disney adaptation of j.m. barrie 's peter pan ."

# %% [markdown]
# predicted to be *very positive* while it's *very negative*, maybe words like *classic* confuses the classifier

# %%
df.loc[686].Text
# Out:
# "whaley 's determination to immerse you in sheer , unrelenting wretchedness is exhausting ."

# %% [markdown]
# predicted to be *very positive* while it's *very negative*, maybe words like *dertermination* confuses the classifier

# %%
df.loc[972].Text
# Out:
# '... routine , harmless diversion and little else .'

# %% [markdown]
# predicted to be *very negative* while it's *positive*, confusion may comes from *little else*
