# %%
from IPython.display import Image

# %% [markdown]
# # (d)

# %%
# !python q3_gru.py predict -c rnn
# !python q3_gru.py predict -c rnn -g
# !python q3_gru.py predict -c gru
# !python q3_gru.py predict -c gru -g

# %%
Image('./q3-noclip-rnn.png')

# %%
Image('./q3-clip-rnn.png')

# %% [markdown]
# In the case of RNN, gradients varnish quickly, so clipping doesn't seem to have an apparent effect.

# %%
Image('./q3-noclip-gru.png')

# %%
Image('./q3-noclip-gru.png')

# %%
Image('./q3-clip-gru.png')

# %% [markdown]
# In contrast, the clipping effect on GRU is apparent. The loss (l2) may not be very useful here, not sure what it would be in terms of latching behavior.

# %% [markdown]
# # (f)
